# %%
# 4 imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fb = pd.read_csv('fb.csv')
fb
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
fb.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
fb.dropna()
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
fb.isnull().sum()
# Removing outliers!!
mask = fb['like'] > 1000
rows_to_drop = fb[mask].index
fb.drop(index=rows_to_drop, axis=0, inplace=True)

# %%
# x = np.array([13,26,37,41,58,67,82])
# y = np.array([23,27,31,46,58,62,79])
# z = np.array([98,78,65,54,48,39,20])

# %%
x = fb['Type'].values[:10]
x.reshape(-1,1)
y = fb['like'].values[:10]
y.reshape(-1,1)
z = fb['share'].values[:10]
z.reshape(-1,1)
# Out:
# array([[17.],
#        [29.],
#        [14.],
#        [49.],
#        [33.],
#        [27.],
#        [14.],
#        [31.],
#        [26.],
#        [19.]])

# %% [markdown]
# ## LINE PLOT

# %%
plt.xlabel('Type of post')
plt.ylabel('Likes Count')
plt.title('Like Share Count')
plt.plot(x,y,color = 'blue', label = 'Likes', marker = 'o', mfc = 'red', ls = '--', ms = 7)
plt.plot(x,z,color = 'black', label = 'Share', marker = 'o', mfc = 'yellow', ls = '--', ms = 7)
plt.grid()
plt.legend()

# %% [markdown]
# ## BAR GRAPH

# %%
plt.xlabel('Type')
plt.ylabel('Likes')
plt.title('Likes Count', fontsize = 20)
plt.bar(x,y,width = 0.3)  # transparency of the bars
plt.grid()

# %% [markdown]
# ## SUB PLOT

# %%
plt.figure(figsize=(16,10))

plt.subplot(2,2,2)
plt.xlabel('Type')
plt.ylabel('Like Count')
plt.title('Like Count Plot')
plt.plot(x,y,color='blue',marker='o',mfc='red',ls='--',ms=7)

plt.subplot(2,2,1)
plt.xlabel('Type')
plt.ylabel('Share Count')
plt.title('Share Count Plot')
plt.plot(x,z,color='black',marker='o',mfc='yellow',ls='--',ms=7)

# %% [markdown]
# ## SCATTER PLOT

# %%
plt.xlabel('Type')
plt.ylabel('Like Count')
plt.scatter(x,y, marker = '>')
plt.grid()

# %% [markdown]
# ## PIE CHART

# %%
mycolor = ['red','green','yellow']
type = ['Photo','Status','Story']
data = [32,45,68]
plt.title('Pie Chart')
plt.pie(data, labels = type, autopct = '%.2f%%', startangle=90, labeldistance=1.1, radius = 0.8, colors = mycolor, shadow = True )
# Out:
# ([<matplotlib.patches.Wedge at 0x14993f710>,
# ...
#  [Text(-0.5624008688153334, 0.6768347381420065, 'Photo'),
#   Text(-0.6188744203761152, -0.6256152586087775, 'Status'),
#   Text(0.8758207627769997, 0.08566207730795769, 'Story')],
#  [Text(-0.30676411026290906, 0.36918258444109436, '22.07%'),
#   Text(-0.33756786565969915, -0.3412446865138786, '31.03%'),
#   Text(0.47772041606018156, 0.04672476944070419, '46.90%')])

# %%
plt.figure(figsize = (16,10))

plt.subplot(2,2,1)
plt.xlabel('Type of post')
plt.ylabel('Likes Count')
plt.title('Like Share Count')
plt.plot(x,y,color = 'blue', label = 'Likes', marker = 'o', mfc = 'red', ls = '--', ms = 7)
plt.plot(x,z,color = 'black', label = 'Share', marker = 'o', mfc = 'yellow', ls = '--', ms = 7)
plt.grid()
plt.legend()

plt.subplot(2,2,2)
plt.xlabel('Type')
plt.ylabel('Likes')
plt.title('Likes Count', fontsize = 20)
plt.bar(x,y,width = 0.3)
plt.grid()

plt.subplot(2,2,3)
plt.xlabel('Type')
plt.ylabel('Like Count')
plt.scatter(x,y, marker = '>')
plt.grid()

plt.subplot(2,2,4)
mycolor = ['red','green','yellow']
type = ['Photo','Status','Story']
data = [32,45,68]
plt.title('Pie Chart')
plt.pie(data, labels = type, autopct = '%.2f%%', startangle=90, labeldistance=1.1, radius = 0.8,
        colors = mycolor, shadow = True );

# %%
plt.savefig('Combined Plot Figure')

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## HEATMAP

# %%
data = {
    'cat1' : [1,2,3,4,5],
    'cat2' : [5,4,3,2,1],
    'cat3' : [2,3,5,1,4],
    'cat4' : [5,3,2,4,1]
}

df = pd.DataFrame(data)

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
corr = df.corr()
corr
# Out:
#       cat1  cat2  cat3  cat4
# cat1   1.0  -1.0   0.2  -0.7
# cat2  -1.0   1.0  -0.2   0.7
# cat3   0.2  -0.2   1.0  -0.8
# cat4  -0.7   0.7  -0.8   1.0

# %% [markdown]
# ## VIOLIN PLOT

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips);
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.pairplot(tips, hue = 'sex', palette = 'Set1');
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
