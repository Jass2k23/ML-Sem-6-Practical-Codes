# %%
import pandas as pd

# %%
air = pd.read_csv('/Users/jass/Downloads/DSBDAL/Assignment 5/airquality.csv')

# %%
air.shape
# Out:
# (153, 7)

# %%
air
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0             1   41.0    190.0   7.4    67      5    1
# 1             2   36.0    118.0   8.0    72      5    2
# 2             3   12.0    149.0  12.6    74      5    3
# 3             4   18.0    313.0  11.5    62      5    4
# 4             5    NaN      NaN  14.3    56      5    5
# ..          ...    ...      ...   ...   ...    ...  ...
# 148         149   30.0    193.0   6.9    70      9   26
# 149         150    NaN    145.0  13.2    77      9   27
# 150         151   14.0    191.0  14.3    75      9   28
# 151         152   18.0    131.0   8.0    76      9   29
# 152         153   20.0    223.0  11.5    68      9   30
#
# [153 rows x 7 columns]

# %% [markdown]
# ## Drop unrequired(unNamed) columns like serial num

# %%
air.drop(['Unnamed: 0'],axis=1,inplace=True)
air.head(11)
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 0    41.0    190.0   7.4    67      5    1
# 1    36.0    118.0   8.0    72      5    2
# 2    12.0    149.0  12.6    74      5    3
# 3    18.0    313.0  11.5    62      5    4
# 4     NaN      NaN  14.3    56      5    5
# 5    28.0      NaN  14.9    66      5    6
# 6    23.0    299.0   8.6    65      5    7
# 7    19.0     99.0  13.8    59      5    8
# 8     8.0     19.0  20.1    61      5    9
# 9     NaN    194.0   8.6    69      5   10
# 10    7.0      NaN   6.9    74      5   11

# %%
air.count()
# Out:
# Ozone      116
# Solar.R    146
# Wind       153
# Temp       153
# Month      153
# Day        153
# dtype: int64

# %%
air.isnull().sum()
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
air.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  116.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.803922
# std     32.987885   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     18.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     31.500000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     63.250000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %% [markdown]
# ## Handling NULL Data

# %%
air.shape
# Out:
# (153, 6)

# %%
A = air.dropna() # removes the entire row, if one of the value is null
A.shape
# Out:
# (111, 6)

# %%
A.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
A = air.fillna(0) # replace all missing values(NaN) in dataframe with 0.
A.shape
# Out:
# (153, 6)

# %%
A.head(11)
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 0    41.0    190.0   7.4    67      5    1
# 1    36.0    118.0   8.0    72      5    2
# 2    12.0    149.0  12.6    74      5    3
# 3    18.0    313.0  11.5    62      5    4
# 4     0.0      0.0  14.3    56      5    5
# 5    28.0      0.0  14.9    66      5    6
# 6    23.0    299.0   8.6    65      5    7
# 7    19.0     99.0  13.8    59      5    8
# 8     8.0     19.0  20.1    61      5    9
# 9     0.0    194.0   8.6    69      5   10
# 10    7.0      0.0   6.9    74      5   11

# %%
A = air.fillna(method = 'pad') # replaces all missing values in dataframe from preceding row
# Out:
# /var/folders/bc/94j5j_112jvcchhwph5jm2j00000gn/T/ipykernel_7624/3108059517.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   A = air.fillna(method = 'pad') # replaces all missing values in dataframe from preceding row

# %%
A.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4   18.0    313.0  14.3    56      5    5

# %%
A = air.fillna(method = 'backfill') # replaces with the values of following row
A.head()
# Out:
# /var/folders/bc/94j5j_112jvcchhwph5jm2j00000gn/T/ipykernel_7624/93862300.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   A = air.fillna(method = 'backfill') # replaces with the values of following row
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4   28.0    299.0  14.3    56      5    5

# %% [markdown]
# ## Replace null values using numpy

# %%
import numpy as np

# %%
A = air['Ozone'].replace(np.NaN,air['Ozone'].mean()) # replace NaN values with the mean of non-missing values
A.head()
# Out:
# 0    41.00000
# 1    36.00000
# 2    12.00000
# 3    18.00000
# 4    42.12931
# Name: Ozone, dtype: float64

# %%
A = air['Ozone'].replace(np.NaN,air['Ozone'].median())  # with median of non-missing values
A.head()
# Out:
# 0    41.0
# 1    36.0
# 2    12.0
# 3    18.0
# 4    31.5
# Name: Ozone, dtype: float64

# %% [markdown]
# ## Impute the missing values

# %%
from sklearn.impute import SimpleImputer as SI

# %%
imp = SI(missing_values=np.NaN,strategy='mean') # calc mean for each col. and tranforms the dataframe
A = imp.fit_transform(air) # stores the result in NumPy array 'A'
A
# Out:
# array([[ 41.        , 190.        ,   7.4       ,  67.        ,
#           5.        ,   1.        ],
#        [ 36.        , 118.        ,   8.        ,  72.        ,
#           5.        ,   2.        ],
#        [ 12.        , 149.        ,  12.6       ,  74.        ,
#           5.        ,   3.        ],
#        [ 18.        , 313.        ,  11.5       ,  62.        ,
#           5.        ,   4.        ],
#        [ 42.12931034, 185.93150685,  14.3       ,  56.        ,
#           5.        ,   5.        ],
#        [ 28.        , 185.93150685,  14.9       ,  66.        ,
#           5.        ,   6.        ],
#        [ 23.        , 299.        ,   8.6       ,  65.        ,
#           5.        ,   7.        ],
#        [ 19.        ,  99.        ,  13.8       ,  59.        ,
#           5.        ,   8.        ],
#        [  8.        ,  19.        ,  20.1       ,  61.        ,
#           5.        ,   9.        ],
# ...

# %%
A = pd.DataFrame(A, columns=air.columns) # converts A into Data frame with the same col. names of air 
A.head()
# Out:
#       Ozone     Solar.R  Wind  Temp  Month  Day
# 0  41.00000  190.000000   7.4  67.0    5.0  1.0
# 1  36.00000  118.000000   8.0  72.0    5.0  2.0
# 2  12.00000  149.000000  12.6  74.0    5.0  3.0
# 3  18.00000  313.000000  11.5  62.0    5.0  4.0
# 4  42.12931  185.931507  14.3  56.0    5.0  5.0

# %%
from sklearn.model_selection import train_test_split

# %%
len(A)
# Out:
# 153

# %%
train,test = train_test_split(A,test_size=0.20)
print(len(train))
print(len(test))
# Out:
# 122
# 31

# %%
train.head()
# Out:
#      Ozone     Solar.R  Wind  Temp  Month   Day
# 117   73.0  215.000000   8.0  86.0    8.0  26.0
# 50    13.0  137.000000  10.3  76.0    6.0  20.0
# 103   44.0  192.000000  11.5  86.0    8.0  12.0
# 73    27.0  175.000000  14.9  81.0    7.0  13.0
# 95    78.0  185.931507   6.9  86.0    8.0   4.0

# %%
A.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  153.000000  153.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.803922
# std     28.693372   87.960267    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     21.000000  120.000000    7.400000   72.000000    6.000000    8.000000
# 50%     42.129310  194.000000    9.700000   79.000000    7.000000   16.000000
# 75%     46.000000  256.000000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
B = scaler.fit_transform(A) 

# performs transformation and normalizes the numerical  values (similar scale),
# usually done before training of the model

# %%
pd.DataFrame(B).describe()
# Out:
#                   0             1             2             3           4  \
# count  1.530000e+02  1.530000e+02  1.530000e+02  1.530000e+02  153.000000
# mean  -2.322035e-17 -1.741526e-17 -2.322035e-17  7.430512e-16    0.000000
# std    1.003284e+00  1.003284e+00  1.003284e+00  1.003284e+00    1.003284
# min   -1.438115e+00 -2.040912e+00 -2.351584e+00 -2.319450e+00   -1.411916
# 25%   -7.388013e-01 -7.520217e-01 -7.283322e-01 -6.235080e-01   -0.703643
# 50%    0.000000e+00  9.203008e-02 -7.333578e-02  1.184665e-01    0.004629
# 75%    1.353414e-01  7.992086e-01  4.392701e-01  7.544446e-01    0.712902
# max    4.401158e+00  1.688885e+00  3.059256e+00  2.026401e+00    1.421174
#
#                   5
# count  1.530000e+02
# mean  -6.966105e-17
# std    1.003284e+00
# min   -1.675504e+00
# 25%   -8.832458e-01
# 50%    2.219211e-02
# 75%    8.144503e-01
# max    1.719888e+00

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data = pd.read_csv('/Users/jass/Downloads/DSBDAL/Assignment 5/student.csv')
data
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
B = le.fit_transform(data['name'])
B
# Out:
# array([6, 2, 5, 0, 8, 9, 1, 3, 4, 7])

# %%
B = data[:]
B
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
B['name'] = le.fit_transform(B['name'])
B
# Out:
#    roll  name class  marks  age
# 0     1     6    TE  56.77   22
# 1     2     2    TE  59.77   21
# 2     3     5    BE  76.88   19
# 3     4     0    TE  69.66   20
# 4     5     8    TE  63.28   20
# 5     6     9    BE  49.55   20
# 6     7     1    BE  65.34   19
# 7     8     3    BE  68.33   23
# 8     9     4    TE  56.75   20
# 9    10     7    BE  78.66   21

# %%
A
# Out:
#         Ozone     Solar.R  Wind  Temp  Month   Day
# 0    41.00000  190.000000   7.4  67.0    5.0   1.0
# 1    36.00000  118.000000   8.0  72.0    5.0   2.0
# 2    12.00000  149.000000  12.6  74.0    5.0   3.0
# 3    18.00000  313.000000  11.5  62.0    5.0   4.0
# 4    42.12931  185.931507  14.3  56.0    5.0   5.0
# ..        ...         ...   ...   ...    ...   ...
# 148  30.00000  193.000000   6.9  70.0    9.0  26.0
# 149  42.12931  145.000000  13.2  77.0    9.0  27.0
# 150  14.00000  191.000000  14.3  75.0    9.0  28.0
# 151  18.00000  131.000000   8.0  76.0    9.0  29.0
# 152  20.00000  223.000000  11.5  68.0    9.0  30.0
#
# [153 rows x 6 columns]

# %% [markdown]
# ## Training Model

# %%
from sklearn.linear_model import LinearRegression

# %%
X = A['Ozone'].values
X = X.reshape(-1,1) # reshape it into single col. array

# %%
Y = A['Temp']

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.score(X,Y) * 100
# Out:
# 37.056682983646425

# %%
X
# Out:
# array([[ 41.        ],
#        [ 36.        ],
#        [ 12.        ],
#        [ 18.        ],
#        [ 42.12931034],
#        [ 28.        ],
#        [ 23.        ],
#        [ 19.        ],
#        [  8.        ],
#        [ 42.12931034],
#        [  7.        ],
#        [ 16.        ],
#        [ 11.        ],
#        [ 14.        ],
#        [ 18.        ],
#        [ 14.        ],
#        [ 34.        ],
#        [  6.        ],
#        [ 30.        ],
#        [ 11.        ],
#        [  1.        ],
#        [ 11.        ],
#        [  4.        ],
#        [ 32.        ],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 23.        ],
#        [ 45.        ],
#        [115.        ],
#        [ 37.        ],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 42.12931034],
#        [ 29.        ],
#        [ 42.12931034],
#        [ 71.        ],
# ...

# %%
model.predict(X).reshape(-1,1)
# Out:
# array([[ 77.65557648],
#        [ 76.65152801],
#        [ 71.83209535],
#        [ 73.03695351],
#        [ 77.88235294],
#        [ 75.04505045],
#        [ 74.04100198],
#        [ 73.23776321],
#        [ 71.02885657],
#        [ 77.88235294],
#        [ 70.82804688],
#        [ 72.63533413],
#        [ 71.63128566],
#        [ 72.23371474],
#        [ 73.03695351],
#        [ 72.23371474],
#        [ 76.24990862],
#        [ 70.62723719],
#        [ 75.44666984],
#        [ 71.63128566],
#        [ 69.62318872],
#        [ 71.63128566],
#        [ 70.2256178 ],
#        [ 75.84828923],
#        [ 77.88235294],
#        [ 77.88235294],
#        [ 77.88235294],
#        [ 74.04100198],
#        [ 78.45881525],
#        [ 92.51549383],
#        [ 76.8523377 ],
#        [ 77.88235294],
#        [ 77.88235294],
#        [ 77.88235294],
#        [ 77.88235294],
#        [ 77.88235294],
#        [ 77.88235294],
#        [ 75.24586015],
#        [ 77.88235294],
#        [ 83.6798673 ],
# ...

# %%
model.predict([[128]])
# Out:
# array([95.12601986])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)

# %% [markdown]
# ## Data Integration

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
db_config = {
    'user' : 'root',
    'password' : 'root',
    'host' : 'localhost',
    'database' : 'mydatabase'
}
# configuration

# %%
connection = mysql.connector.connect(**db_config)
# connecting
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/connection_cext.py:327, in CMySQLConnection._open_connection(self)
#     326 try:
# --> 327     self._cmysql.connect(**cnx_kwargs)
#     328     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (61)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 connection = mysql.connector.connect(**db_config)
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/pooling.py:322, in connect(*args, **kwargs)
#     319         raise ImportError(ERROR_NO_CEXT)
#     321 if CMySQLConnection and not use_pure:
# ...

# %%
cursor = connection.cursor()
#creating cursor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 cursor = connection.cursor()
#
# NameError: name 'connection' is not defined

# %%
insert_query = "insert into users(username,email) values (%s,%s)"

# %%
users_data = {
    ('akash','akash@xyz.com'),
    ('raj','raj@gmail.com')
}

# %%
cursor.executemany(insert_query,users_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 cursor.executemany(insert_query,users_data)
#
# NameError: name 'cursor' is not defined

# %%
connection.commit()
#commiting
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 connection.commit()
#
# NameError: name 'connection' is not defined

# %%
cursor.execute("select * from users")
#executing a command
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 cursor.execute("select * from users")
#
# NameError: name 'cursor' is not defined

# %%
result = cursor.fetchall()
result
# fetching the results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 result = cursor.fetchall()
#       2 result
#
# NameError: name 'cursor' is not defined

# %%
cursor.close()
connection.close()
#closing the connection
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 cursor.close()
#       2 connection.close()
#
# NameError: name 'cursor' is not defined
